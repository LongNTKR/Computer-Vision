# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.2/611.2 kB 9.6 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
import os

folder_path = "/content/drive/MyDrive/Colab Notebooks/Object Detection/data/train" # resize images in train and test dataset

desired_size = (256, 256)


file_list = os.listdir(folder_path)


for file_name in file_list:

    if file_name.endswith(('.png', '.jpg', '.jpeg')):

        image_path = os.path.join(folder_path, file_name)
        image = Image.open(image_path)
        image = image.convert('RGB')
        resized_image = image.resize(desired_size)

        output_path = os.path.join(folder_path, file_name)
        resized_image.save(output_path)

        print(f"Resized {file_name} and saved to {output_path}")

print("Image resizing completed.")
# Out:
# Image resizing completed.

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Object Detection
# Out:
# /content/drive/MyDrive/Colab Notebooks/Object Detection

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Object Detection

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=256 plots=True
# Out:
# /content/drive/MyDrive/Colab Notebooks/Object Detection
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
Image(filename="/content/drive/MyDrive/Colab Notebooks/Object Detection/runs/detect/train2/confusion_matrix.png", width=600)

# %%
Image(filename="/content/drive/MyDrive/Colab Notebooks/Object Detection/runs/detect/train2/results.png", width=600)

# %%
Image(filename="/content/drive/MyDrive/Colab Notebooks/Object Detection/runs/detect/train2/val_batch0_pred.jpg", width=600)

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
#
# image 1/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_77.jpg: 512x640 4 apples, 526.0ms
# image 2/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_78.jpg: 640x640 2 apples, 632.1ms
# libpng warning: iCCP: known incorrect sRGB profile
# image 3/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_79.jpg: 640x640 2 apples, 600.6ms
# image 4/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_80.jpg: 544x640 1 apple, 495.1ms
# image 5/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_81.jpg: 640x576 3 apples, 778.1ms
# image 6/60 /content/drive/MyDrive/Colab Notebooks/Object Detection/data/test/images/apple_82.jpg: 640x576 1 apple, 1 orange, 943.5ms
# ...
